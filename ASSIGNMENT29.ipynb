# %%
from bs4 import BeautifulSoup
import urllib.request
import nltk
import re
from collections import Counter
response = urllib.request.urlopen('http://php.net/')
html = response.read()
soup = BeautifulSoup(html,"html5lib")

# %%
text = soup.getText()

# %%
#extract words from textCounter(words)
words = re.findall(r'\w+', text.lower())

# %%
#first show top 10 most common words
Counter(words).most_common(10)
# Out:
# [('the', 191),
#  ('php', 140),
#  ('7', 76),
#  ('of', 75),
#  ('release', 68),
#  ('for', 68),
#  ('in', 57),
#  ('and', 56),
#  ('can', 50),
#  ('this', 46)]

# %%
Counter(words)
# Out:
# Counter({'php': 140,
#          'hypertext': 1,
#          'preprocessor': 1,
#          'downloads': 26,
#          'documentation': 1,
#          'get': 1,
#          'involved': 1,
#          'help': 2,
#          'getting': 1,
#          'started': 2,
#          'introduction': 2,
#          'a': 30,
#          'simple': 1,
#          'tutorial': 1,
#          'language': 3,
#          'reference': 2,
#          'basic': 2,
#          'syntax': 1,
#          'types': 1,
#          'variables': 2,
#          'constants': 1,
#          'expressions': 1,
#          'operators': 1,
#          'control': 2,
#          'structures': 1,
#          'functions': 1,
#          'classes': 2,
#          'and': 56,
#          'objects': 1,
#          'namespaces': 1,
#          'errors': 1,
#          'exceptions': 2,
#          'generators': 1,
#          'references': 1,
#          'explained': 1,
#          'predefined': 3,
#          'interfaces': 1,
#          'context': 1,
#          'options': 1,
#          'parameters': 1,
#          'supported': 1,
#          'protocols': 1,
#          'wrappers': 1,
#          'security': 11,
#          'general': 2,
#          'considerations': 1,
#          'installed': 2,
#          'as': 2,
#          'cgi': 1,
#          'binary': 1,
#          'an': 2,
#          'apache': 1,
#          'module': 1,
#          'session': 2,
#          'filesystem': 1,
#          'database': 3,
#          'error': 1,
#          'reporting': 7,
#          'using': 2,
#          'register': 1,
#          'globals': 1,
#          'user': 2,
#          'submitted': 1,
#          'data': 1,
#          'magic': 1,
#          'quotes': 1,
#          'hiding': 1,
#          'keeping': 1,
#          'current': 2,
#          'features': 12,
#          'http': 1,
#          'authentication': 2,
#          'with': 3,
#          'cookies': 1,
#          'sessions': 1,
#          'dealing': 1,
#          'xforms': 1,
#          'handling': 2,
#          'file': 25,
#          'uploads': 1,
#          'remote': 1,
#          'files': 12,
#          'connection': 1,
#          'persistent': 1,
#          'connections': 1,
#          'safe': 1,
#          'mode': 1,
#          'command': 2,
#          'line': 2,
#          'usage': 1,
#          'garbage': 1,
#          'collection': 1,
#          'dtrace': 1,
#          'dynamic': 1,
#          'tracing': 1,
#          'function': 1,
#          'affecting': 1,
#          's': 2,
#          'behaviour': 1,
#          'audio': 1,
#          'formats': 1,
#          'manipulation': 2,
#          'services': 3,
#          'specific': 2,
#          'extensions': 16,
#          'compression': 1,
#          'archive': 12,
#          'credit': 1,
#          'card': 1,
#          'processing': 3,
#          'cryptography': 1,
#          'date': 1,
#          'time': 1,
#          'related': 4,
#          'system': 12,
#          'human': 1,
#          'character': 1,
#          'encoding': 1,
#          'support': 1,
#          'image': 1,
#          'generation': 1,
#          'mail': 1,
#          'mathematical': 1,
#          'non': 1,
#          'text': 2,
#          'mime': 1,
#          'output': 1,
#          'process': 1,
#          'other': 14,
#          'search': 3,
#          'engine': 1,
#          'server': 1,
#          'variable': 1,
#          'type': 1,
#          'web': 2,
#          'windows': 35,
#          'only': 1,
#          'xml': 1,
#          'gui': 1,
#          'keyboard': 1,
#          'shortcuts': 1,
#          'this': 46,
#          'j': 1,
#          'next': 10,
#          'menu': 2,
#          'item': 2,
#          'k': 1,
#          'previous': 2,
#          'g': 7,
#          'p': 1,
#          'man': 2,
#          'page': 21,
#          'n': 1,
#          'scroll': 2,
#          'to': 30,
#          'bottom': 1,
#          'top': 1,
#          'h': 1,
#          'goto': 2,
#          'homepage': 1,
#          'focus': 1,
#          'box': 1,
#          'is': 43,
#          'popular': 2,
#          'purpose': 1,
#          'scripting': 1,
#          'that': 1,
#          'especially': 1,
#          'suited': 1,
#          'development': 23,
#          'fast': 1,
#          'flexible': 1,
#          'pragmatic': 1,
#          'powers': 1,
#          'everything': 1,
#          'from': 1,
#          'your': 1,
#          'blog': 1,
#          'the': 191,
#          'most': 1,
#          'websites': 1,
#          'in': 57,
#          'world': 2,
#          'download': 19,
#          '5': 6,
#          '6': 5,
#          '37': 4,
#          'release': 68,
#          'notes': 15,
#          'upgrading': 27,
#          '7': 76,
#          '0': 41,
#          '31': 5,
#          '1': 17,
#          '21': 6,
#          '2': 41,
#          '9': 4,
#          '17': 2,
#          'aug': 6,
#          '2018': 15,
#          'released': 21,
#          'team': 18,
#          'announces': 12,
#          'immediate': 12,
#          'availability': 12,
#          'of': 75,
#          'bugfix': 3,
#          'all': 12,
#          'users': 12,
#          'are': 13,
#          'encouraged': 12,
#          'upgrade': 7,
#          'version': 26,
#          'for': 68,
#          'source': 25,
#          'please': 25,
#          'visit': 18,
#          'our': 12,
#          'binaries': 17,
#          'can': 50,
#          'be': 45,
#          'found': 40,
#          'on': 40,
#          'net': 19,
#          'list': 23,
#          'changes': 19,
#          'recorded': 7,
#          'changelog': 7,
#          '16': 2,
#          '3': 43,
#          'beta2': 1,
#          'glad': 6,
#          'announce': 6,
#          'sixth': 1,
#          '0beta2': 2,
#          'rough': 6,
#          'outline': 6,
#          'cycle': 6,
#          'specified': 6,
#          'wiki': 11,
#          'sources': 10,
#          'qa': 16,
#          'carefully': 11,
#          'test': 12,
#          'report': 11,
#          'any': 11,
#          'issues': 6,
#          'bug': 13,
#          'preview': 10,
#          'do': 11,
#          'not': 11,
#          'use': 11,
#          'it': 11,
#          'production': 11,
#          'more': 10,
#          'information': 11,
#          'new': 11,
#          'you': 27,
#          'read': 16,
#          'news': 12,
#          'or': 17,
#          'complete': 11,
#          'internal': 1,
#          'listed': 1,
#          'internals': 1,
#          'these': 11,
#          'also': 17,
#          'would': 6,
#          'beta': 9,
#          'planned': 11,
#          'august': 4,
#          '30th': 1,
#          'signatures': 6,
#          'manifest': 6,
#          'site': 6,
#          'thank': 11,
#          'helping': 11,
#          'us': 11,
#          'make': 11,
#          'better': 11,
#          '02': 1,
#          'beta1': 1,
#          'fifth': 1,
#          '0beta1': 2,
#          '16th': 1,
#          '20': 5,
#          'jul': 7,
#          'several': 5,
#          'bugs': 8,
#          'have': 3,
#          'been': 3,
#          'fixed': 3,
#          '19': 3,
#          '8': 3,
#          'which': 2,
#          'contains': 2,
#          'minor': 1,
#          'fixes': 3,
#          '0alpha4': 3,
#          'fourth': 2,
#          '2nd': 1,
#          '05': 1,
#          'alpha': 15,
#          'third': 3,
#          'july': 3,
#          '19th': 1,
#          'jun': 2,
#          'second': 2,
#          '07': 1,
#          'first': 4,
#          'starts': 1,
#          'early': 1,
#          'june': 1,
#          '01': 1,
#          'feb': 1,
#          'included': 1,
#          '12': 1,
#          'oct': 1,
#          '2017': 5,
#          'candidate': 14,
#          '4': 2,
#          'rc4': 1,
#          'incompatibilities': 5,
#          'tracking': 5,
#          'at': 4,
#          'will': 5,
#          'announced': 2,
#          '26th': 1,
#          'october': 2,
#          'full': 5,
#          'releases': 5,
#          '28': 1,
#          'sep': 1,
#          'rc3': 1,
#          '12th': 1,
#          '14th': 1,
#          'september': 1,
#          'final': 1,
#          '31th': 1,
#          '06': 1,
#          'improvements': 1,
#          'relative': 1,
#          '20th': 1,
#          'older': 1,
#          'entries': 1,
#          'upcoming': 1,
#          'conferencesphp': 1,
#          '2018northeast': 1,
#          'boston': 1,
#          '2018zendcon': 1,
#          'openenterprise': 1,
#          '2018symfonycon': 1,
#          'lisbon': 1,
#          'conferences': 1,
#          'calling': 1,
#          'paperssunshinephp': 1,
#          '2019': 1,
#          'cfp': 1,
#          'group': 2,
#          'events': 1,
#          'special': 1,
#          'thanks': 1,
#          'social': 1,
#          'media': 1,
#          'official_php': 1,
#          'copyright': 1,
#          '2001': 1,
#          'my': 1,
#          'contact': 1,
#          'sites': 2,
#          'mirror': 1,
#          'privacy': 1,
#          'policy': 1})
